# %%
# !pip install pandas
# Out:
# ...
#      |████████████████████████████████| 12.4 MB 16.1 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 17.3 MB 41.6 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 502 kB 62.0 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 346 kB 64.0 MB/s eta 0:00:01
# ...
#   WARNING: The scripts f2py, f2py3 and f2py3.8 are installed in '/config/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# ...

# %%
import pandas as pd

# %%
#most powerfull library usefull in different diffrerrnt dataset operation
#here we deal with different different types of files 
#pandas is the kind of library which will be able to handle all of this file read write manipulation filter each and every kind of operation in a easy possible ways

# %%
# from google.colab import drive
# drive.mount('/content/drive/')

# %%
ls
# Out:
#  cricket.csv        'Pandas Data Analysis.ipynb'   SampleCSV/
#  Json_Response.csv   Pandas_Introduction.ipynb     SampleExcel/
#  NBA.csv            'sample_|.csv'                 sample_test.csv

# %%
#CSV are comma separated files
pd.read_csv('sample_test.csv')
# Out:
#         name                emailid    address  pin code       sirname
# 0  sudhanshu  SSKUMAR9876@GMAIL.COM  Bengalore    560085         kumar
# 1      krish        krish@gmail.com  bengalore    560085          naik
# 2    ineuron     ineuron@ineuron.ai  Bengalore    560085  intelligence
# 3     pandas      pandas@ineuron.ai    chennai  25845121      tutorial

# %% [markdown]
# Files :
#
# sample csv file - https://github.com/codeforamerica/ohana-api/tree/master/data/sample-csv <br>
# Titanic - https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv <br>
# excel file - https://github.com/finbourne/sample-excel

# %%
pd.read_csv(r'SampleCSV/locations.csv')
#by default first row will be treated as a column name
# Out:
#     id  organization_id                                      accessibility  \
# 0    1                1       disabled_parking, ramp, restroom, wheelchair
# 1    2                1                                         wheelchair
# 2    3                1                                                NaN
# 3    4                1                                         wheelchair
# 4    5                1                                         wheelchair
# 5    6                2                       disabled_parking, wheelchair
# 6    7                2       ramp, restroom, disabled_parking, wheelchair
# 7    8                2                                                NaN
# 8    9                3                         ramp, restroom, wheelchair
# 9   10                3  elevator, tape_braille, ramp, restroom, disabl...
# 10  11                3                                               ramp
# ...

# %%
#but suppose if I have a file without column name, then we can call some parameter to solve this as follow
pd.read_csv('sample_test.csv',header=None)

#here it has given default column name 0 1 2 3 4
#but we can customise that too
# Out:
#            0                      1          2         3             4
# 0       name                emailid    address  pin code       sirname
# 1  sudhanshu  SSKUMAR9876@GMAIL.COM  Bengalore    560085         kumar
# 2      krish        krish@gmail.com  bengalore    560085          naik
# 3    ineuron     ineuron@ineuron.ai  Bengalore    560085  intelligence
# 4     pandas      pandas@ineuron.ai    chennai  25845121      tutorial

# %%
#customised column name
pd.read_csv('sample_test.csv',names=['a','b','c','d','e'])
# Out:
#            a                      b          c         d             e
# 0       name                emailid    address  pin code       sirname
# 1  sudhanshu  SSKUMAR9876@GMAIL.COM  Bengalore    560085         kumar
# 2      krish        krish@gmail.com  bengalore    560085          naik
# 3    ineuron     ineuron@ineuron.ai  Bengalore    560085  intelligence
# 4     pandas      pandas@ineuron.ai    chennai  25845121      tutorial

# %%
pd.read_csv('sample_test.csv',names=['a','b','c'])
# Out:
#                                          a         b             c
# name      emailid                  address  pin code       sirname
# sudhanshu SSKUMAR9876@GMAIL.COM  Bengalore    560085         kumar
# krish     krish@gmail.com        bengalore    560085          naik
# ineuron   ineuron@ineuron.ai     Bengalore    560085  intelligence
# pandas    pandas@ineuron.ai        chennai  25845121      tutorial

# %%
 #limitation of pandas is that it is usefull for structured format data only

# %%
#entire table created by pandas is called data frmae

# %%
a = pd.read_csv(r'SampleCSV/services.csv')
type(a)

#dataframe simply means table
# Out:
# pandas.core.frame.DataFrame

# %%
#suppose we have a CSV file separated with '|'
pd.read_csv('sample_|.csv',sep = '|')
#by default sep = ','
# Out:
#         name                emailid    address  pin code       sirname
# 0  sudhanshu  SSKUMAR9876@GMAIL.COM  Bengalore    560085         kumar
# 1      krish        krish@gmail.com  bengalore    560085          naik
# 2    ineuron     ineuron@ineuron.ai  Bengalore    560085  intelligence
# 3     pandas      pandas@ineuron.ai    chennai  25845121      tutorial

# %%
pd.read_csv('sample_|.csv',sep='|' , skiprows=[1,3])
# Out:
#      name            emailid    address  pin code   sirname
# 0   krish    krish@gmail.com  bengalore    560085      naik
# 1  pandas  pandas@ineuron.ai    chennai  25845121  tutorial

# %%
df = pd.read_csv('SampleCSV/services.csv')
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.dtypes
#in pandas object simply means string
# Out:
# id                           int64
# location_id                  int64
# program_id                 float64
# accepted_payments           object
# alternate_name              object
# application_process         object
# audience                    object
# description                 object
# eligibility                 object
# email                       object
# fees                        object
# funding_sources             object
# interpretation_services     object
# keywords                    object
# languages                   object
# name                        object
# required_documents          object
# service_areas               object
# status                      object
# wait_time                   object
# website                     object
# taxonomy_ids                object
# dtype: object

# %%
#in case of pandas string data types is called object

# %%
df
# Out:
#     id  location_id  program_id         accepted_payments  \
# 0    1            1         NaN                       NaN
# 1    2            2         NaN                       NaN
# 2    3            3         NaN                       NaN
# 3    4            4         NaN                       NaN
# 4    5            5         NaN                       NaN
# 5    6            6         NaN                       NaN
# 6    7            7         NaN                       NaN
# 7    8            8         NaN                       NaN
# 8    9            9         NaN                       NaN
# 9   10           10         NaN                       NaN
# 10  11           11         NaN                       NaN
# 11  12           12         NaN                       NaN
# 12  13           13         NaN                       NaN
# 13  14           14         NaN                       NaN
# 14  15           15         NaN                       NaN
# ...

# %%
df.head(2)
#bydefault head() will show 5 columns
# Out:
#    id  location_id  program_id accepted_payments alternate_name  \
# 0   1            1         NaN               NaN            NaN
# 1   2            2         NaN               NaN            NaN
#
#                   application_process  \
# 0          Walk in or apply by phone.
# 1  Apply by phone for an appointment.
#
#                                             audience  \
# 0  Older adults age 55 or over, ethnic minorities...
# 1       Residents of San Mateo County age 55 or over
#
#                                          description  \
# 0  A walk-in center for older adults that provide...
# 1  Provides training and job placement to eligibl...
#
#                                          eligibility email  ...  \
# 0  Age 55 or over for most programs, age 60 or ov...   NaN  ...
# 1  Age 55 or over, county resident and willing an...   NaN  ...
#
#   interpretation_services                                           keywords  \
# ...

# %%
df.tail(3)
# Out:
#     id  location_id  program_id         accepted_payments  \
# 20  21           21         NaN                       NaN
# 21  22           22         NaN  Cash, Check, Credit Card
# 22  23           22         NaN                       NaN
#
#            alternate_name                application_process  \
# 20                    NaN    By phone during business hours.
# 21  Fotos para pasaportes  Walk in or apply by phone or mail
# 22                    NaN  Walk in or apply by phone or mail
#
#                                              audience  \
# 20                                                NaN
# 21  Profit and nonprofit businesses, the public, m...
# 22  Second service and nonprofit businesses, the p...
#
#                                           description eligibility  \
# 20                                just a test service         NaN
# 21  [NOTE THIS IS NOT A REAL SERVICE--THIS IS FOR ...         NaN
# ...

# %%
# head upar se kitna data chaiye 
# tail niche se kitna data chaiye

# %%
df.columns
# Out:
# Index(['id', 'location_id', 'program_id', 'accepted_payments',
#        'alternate_name', 'application_process', 'audience', 'description',
#        'eligibility', 'email', 'fees', 'funding_sources',
#        'interpretation_services', 'keywords', 'languages', 'name',
#        'required_documents', 'service_areas', 'status', 'wait_time', 'website',
#        'taxonomy_ids'],
#       dtype='object')

# %%
#to access one column
df["name"]
# Out:
# 0          Fair Oaks Adult Activity Center
# 1         Second Career Employment Program
# 2                   Senior Peer Counseling
# 3                 Family Visitation Center
# 4        Economic Self-Sufficiency Program
# 5     Little House Recreational Activities
# 6         Rosener House Adult Day Services
# 7           Meals on Wheels - South County
# 8                         Fair Oaks Branch
# 9                             Main Library
# 10                         Schaberg Branch
# 11                            Project Read
# 12                   Redwood Shores Branch
# 13                      Redwood City Corps
# 14             Adult Rehabilitation Center
# 15                         Sunnyvale Corps
# 16       South San Francisco Citadel Corps
# 17                           Project Smile
# 18           San Mateo Free Medical Clinic
# 19               Service with blank fields
# 20         Service for Admin Test Location
# 21                         Passport Photos
# ...

# %%
#to access one column
a = df["name"]
type(a)
# series is equivalant to list , one single row and one single column
# Out:
# pandas.core.series.Series

# %%
#to access multiple column we have to pass a list of column names
df1 = df[["name" ,'location_id','id' ]]
df1
# Out:
#                                     name  location_id  id
# 0        Fair Oaks Adult Activity Center            1   1
# 1       Second Career Employment Program            2   2
# 2                 Senior Peer Counseling            3   3
# 3               Family Visitation Center            4   4
# 4      Economic Self-Sufficiency Program            5   5
# 5   Little House Recreational Activities            6   6
# 6       Rosener House Adult Day Services            7   7
# 7         Meals on Wheels - South County            8   8
# 8                       Fair Oaks Branch            9   9
# 9                           Main Library           10  10
# 10                       Schaberg Branch           11  11
# 11                          Project Read           12  12
# 12                 Redwood Shores Branch           13  13
# 13                    Redwood City Corps           14  14
# 14           Adult Rehabilitation Center           15  15
# ...

# %%
type(df1)
# Out:
# pandas.core.frame.DataFrame

# %%
b = df[['name']]
type(b)
# Out:
# pandas.core.frame.DataFrame

# %%
#double bracket = data frame , single bracket = series

# %%
#when I was reading excel file it shows the error to install this
# !pip install openpyxl
# Out:
# ...
#      |████████████████████████████████| 249 kB 19.8 MB/s eta 0:00:01
# ...

# %%
#Each Sample Excel file in SampleExcel folder contains multiple sheet
pd.read_excel("SampleExcel/LUSID Excel - Manage Orders.xlsx")
# Out:
#     Unnamed: 0                                   Unnamed: 1  \
# 0          NaN  This sheet allows you to manage executions:
# 1          NaN                           1. List executions
# 2          NaN                             2. Get execution
# 3          NaN                         3. Upsert executions
# 4          NaN                                          NaN
# ..         ...                                          ...
# 65         NaN                                          NaN
# 66         NaN                                          NaN
# 67         NaN                                          NaN
# 68         NaN                                          NaN
# 69         NaN                                          NaN
#
#            Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7  \
# 0                 NaN        NaN        NaN        NaN        NaN        NaN
# 1                 NaN        NaN        NaN        NaN        NaN        NaN
# ...

# %%
# by default pandas read 1st excel sheet but using sheet_name we can extract data from other excel sheet

# %%
pd.read_excel("SampleExcel/LUSID Excel - Manage Orders.xlsx", sheet_name = "Allocations")
# Out:
#     Unnamed: 0                                    Unnamed: 1       Unnamed: 2  \
# 0          NaN  This sheet allows you to manage Allocations:              NaN
# 1          NaN                            1. ListAllocations              NaN
# 2          NaN                              2. GetAllocation              NaN
# 3          NaN                          3. UpsertAllocations              NaN
# 4          NaN                                           NaN              NaN
# ..         ...                                           ...              ...
# 60         NaN                                           NaN              NaN
# 61         NaN                                           NaN              NaN
# 62         NaN                                           NaN             Code
# 63         NaN                                           NaN  MyAllocation001
# 64         NaN                                           NaN  MyAllocation002
#
# ...

# %%
df = pd.ExcelFile("SampleExcel/LUSID Excel - Manage Orders.xlsx")

# %%
#how we can get all sheet names
df.sheet_names
# Out:
# ['Executions', 'Orders', 'Allocations', 'Placements', 'Blocks']

# %%
for i in df.sheet_names:
  pd.read_excel("SampleExcel/LUSID Excel - Manage Orders.xlsx" , sheet_name =   i)

# %%
#Reading CSV from online location
pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")
#this link is taken from Github, always remember to copy link in raw form.
#whenever you open any file in github, there is an option to open in raw mode
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# #Read Html

# %%
# !pip install lxml
# Out:
# ...
#      |████████████████████████████████| 8.0 MB 19.2 MB/s eta 0:00:01
# ...

# %%
pd.read_html("https://www.basketball-reference.com/leagues/")
# Out:
# [   Unnamed: 0_level_0 Unnamed: 1_level_0     Unnamed: 2_level_0  \
#                 Season                 Lg               Champion
#  0             2023-24                NBA                    NaN
#  1             2022-23                NBA         Denver Nuggets
#  2             2021-22                NBA  Golden State Warriors
#  3             2020-21                NBA        Milwaukee Bucks
#  4             2019-20                NBA     Los Angeles Lakers
#  ..                ...                ...                    ...
#  82            1950-51                NBA       Rochester Royals
#  83            1949-50                NBA     Minneapolis Lakers
#  84            1948-49                BAA     Minneapolis Lakers
#  85            1947-48                BAA      Baltimore Bullets
#  86            1946-47                BAA  Philadelphia Warriors
#
#         Award Winners                              Top Performers  \
# ...

# %%
#this data is not in readable format
#it is storing all tables from the website in list format
df = pd.read_html("https://www.basketball-reference.com/leagues/")
type(df)
# Out:
# list

# %%
#data is in list format , I am not happy with this format , i want full tabular form of data

# %%
len(df)
# Out:
# 1

# %%
df[0]
#Now looking good
# Out:
#    Unnamed: 0_level_0 Unnamed: 1_level_0     Unnamed: 2_level_0  \
#                Season                 Lg               Champion
# 0             2023-24                NBA                    NaN
# 1             2022-23                NBA         Denver Nuggets
# 2             2021-22                NBA  Golden State Warriors
# 3             2020-21                NBA        Milwaukee Bucks
# 4             2019-20                NBA     Los Angeles Lakers
# ..                ...                ...                    ...
# 82            1950-51                NBA       Rochester Royals
# 83            1949-50                NBA     Minneapolis Lakers
# 84            1948-49                BAA     Minneapolis Lakers
# 85            1947-48                BAA      Baltimore Bullets
# 86            1946-47                BAA  Philadelphia Warriors
#
#        Award Winners                              Top Performers  \
#                  MVP Rookie of the Year                   Points
# ...

# %%
type(df[0])
# Out:
# pandas.core.frame.DataFrame

# %%
# read_table() sirf tabular data ko hi read karta hai
# whatever data is available in table tag

# %%
df1 = df[0]
df1.columns
# Out:
# MultiIndex([('Unnamed: 0_level_0',             'Season'),
#             ('Unnamed: 1_level_0',                 'Lg'),
#             ('Unnamed: 2_level_0',           'Champion'),
#             (     'Award Winners',                'MVP'),
#             (     'Award Winners', 'Rookie of the Year'),
#             (    'Top Performers',             'Points'),
#             (    'Top Performers',           'Rebounds'),
#             (    'Top Performers',            'Assists'),
#             (    'Top Performers',         'Win Shares')],
#            )

# %%
df1.head()
# Out:
#   Unnamed: 0_level_0 Unnamed: 1_level_0     Unnamed: 2_level_0  \
#               Season                 Lg               Champion
# 0            2023-24                NBA                    NaN
# 1            2022-23                NBA         Denver Nuggets
# 2            2021-22                NBA  Golden State Warriors
# 3            2020-21                NBA        Milwaukee Bucks
# 4            2019-20                NBA     Los Angeles Lakers
#
#       Award Winners                              Top Performers  \
#                 MVP Rookie of the Year                   Points
# 0               NaN                NaN  G. Antetokounmpo (1216)
# 1         J. Embiid        P. Banchero          J. Tatum (2225)
# 2          N. Jokić          S. Barnes          T. Young (2155)
# 3          N. Jokić            L. Ball          S. Curry (2015)
# 4  G. Antetokounmpo          J. Morant         J. Harden (2335)
#
#
#            Rebounds              Assists        Win Shares
# ...

# %%
df1.tail(3)
# Out:
#    Unnamed: 0_level_0 Unnamed: 1_level_0     Unnamed: 2_level_0 Award Winners  \
#                Season                 Lg               Champion           MVP
# 84            1948-49                BAA     Minneapolis Lakers           NaN
# 85            1947-48                BAA      Baltimore Bullets           NaN
# 86            1946-47                BAA  Philadelphia Warriors           NaN
#
#                             Top Performers                               \
#    Rookie of the Year               Points Rebounds             Assists
# 84         H. Shannon      G. Mikan (1698)      NaN     B. Davies (321)
# 85         P. Hoffman  M. Zaslofsky (1007)      NaN    H. Dallmar (120)
# 86                NaN      J. Fulks (1389)      NaN  E. Calverley (202)
#
#
#            Win Shares
# 84    G. Mikan (20.9)
# 85  B. Feerick (10.5)
# 86  B. Feerick (18.6)

# %%
df1.dtypes
# Out:
# Unnamed: 0_level_0  Season                object
# Unnamed: 1_level_0  Lg                    object
# Unnamed: 2_level_0  Champion              object
# Award Winners       MVP                   object
#                     Rookie of the Year    object
# Top Performers      Points                object
#                     Rebounds              object
#                     Assists               object
#                     Win Shares            object
# dtype: object

# %%
df1[["Unnamed: 0_level_0" , "Unnamed: 1_level_0"]]
# Out:
#    Unnamed: 0_level_0 Unnamed: 1_level_0
#                Season                 Lg
# 0             2023-24                NBA
# 1             2022-23                NBA
# 2             2021-22                NBA
# 3             2020-21                NBA
# 4             2019-20                NBA
# ..                ...                ...
# 82            1950-51                NBA
# 83            1949-50                NBA
# 84            1948-49                BAA
# 85            1947-48                BAA
# 86            1946-47                BAA
#
# [87 rows x 2 columns]

# %%
#to store data in csv file to see the whole data
df1.to_csv("NBA.csv")
# #to remove indexes we can use the command index = false 
# df1.to_csv("NBA.csv",index = false )

# %%
df5 = pd.read_html('https://stats.espncricinfo.com/ci/engine/records/averages/batting.html?class=3;id=6;type=team')

# %%
df5[0]
# Out:
#                 Player       Span  Mat Inns  NO  Runs   HS    Ave      SR 100  \
# 0           AB Agarkar  2006-2007    4    2   0    15   14   7.50  136.36   -
# 1             KK Ahmed  2018-2019   14    1   1     1   1*      -  100.00   -
# 2            S Aravind  2015-2015    1    -   0     -    -      -    0.00   -
# 3       Arshdeep Singh  2022-2024   44   12   8    34   12   8.50  125.92   -
# 4             R Ashwin  2010-2022   65   19  12   184  31*  26.28  115.00   -
# ..                 ...        ...  ...  ...  ..   ...  ...    ...     ...  ..
# 105      R Vinay Kumar  2010-2013    9    1   1     2   2*      -   50.00   -
# 106  Washington Sundar  2017-2024   42   15   5   107   50  10.70  150.70   -
# 107           SA Yadav  2021-2023   60   57  10  2141  117  45.55  171.55   4
# 108           UT Yadav  2012-2022    9    2   1    22  20*  22.00  104.76   -
# 109       Yuvraj Singh  2007-2017   58   51   9  1177  77*  28.02  136.38   -
#
#      50  0
# 0     -  -
# ...

# %%
len(df5)
# Out:
# 1

# %%
df5[0].to_csv("cricket.csv", index = False)

# %%
d ="""
{"name" : "Sudhanshu kumar" , 
"email id " : "sskumar@gmail.com",
"tech" : ["ML" , "DL" , "CV" ],
"plateform" : ["techneuron" , "kidsneuron" , "ineuron"]
}"""

#Remember to use double quote to store any string
#single quote will give error
# we have to convert this data into data frame format

# %%
# pd.DataFrame(d)
#we have to import JSON to perform this, otherwise it will give error

# %%
import json
#javascript Object notation , a file system or a data which is avialable in a dictionary format , that is called JSON
# across industry its been use a lot because it is one of the light weight format to transfer a data from one place to another 
#previously we are using a XMl format to transfer a data from one format to another format

# %%
#always remember to validate json otherwise it causes an error
#there are many websites available online to validate json

# %%
result = json.loads(d)

# %%
type(result)
# Out:
# dict

# %%
pd.DataFrame(result)
#always remember it will give error if no. of values in any key will differnt from other keys
#i.e. all keys should have equal no. of values
#but if any key has only one value then fine bcz it will copy that value to match the no. of values in ther keys. This is called as flaterning a data
#just try to observe the output for better understanding
# Out:
#               name          email id  tech   plateform
# 0  Sudhanshu kumar  sskumar@gmail.com   ML  techneuron
# 1  Sudhanshu kumar  sskumar@gmail.com   DL  kidsneuron
# 2  Sudhanshu kumar  sskumar@gmail.com   CV     ineuron

# %%
result['name']
# Out:
# 'Sudhanshu kumar'

# %%
pd.DataFrame(result['tech'])
# Out:
#     0
# 0  ML
# 1  DL
# 2  CV

# %%
result['tech']
# Out:
# ['ML', 'DL', 'CV']

# %%
d2 ="""{"packetType":"D","data":{"checkEngineLightFlag":"F","batteryVoltageStableTime":0,"batteryVoltageStable":"0","batteryVoltageOff":"12.42","batteryCrankParamTN":"-0.08","batteryCrankParamVN":"0.00","batteryCrankParamTP":"-0.08","batteryCrankParamVP":"0.00","batteryCrankParamTT":"-0.00008","batteryCrankParamV0":"0.00","batteryVoltageMaxOn":"13.05","batteryVoltageMinOn":"12.97","batteryVoltageMaxOff":"12.46","batteryVoltageMinOff":"12.36","batteryVoltageOnAverage":"13.02","engineLoadMax":"84","engineLoadAverage":"39.98","rpmMax":"3487","rpmAverage":"1431.29","gpsSpeedAverage":"21.99","vssMax":"53.44","vssAverage":"23.06","tcuTemperatureMin":"82.40","tcuTemperatureMax":"109.40","tcuTemperatureAverage":"104.87","coolantMin":"158.00","coolantMax":"188.60","coolantAverage":"180.20","packetStartLocal":1508143346000,"tripStartLocal":1508143346000,"milIndicator":"F","monitorsNotReady":0,"imei":"60DF5417","gatewayTs":1515613306592,"diagnosticTroubleCodeData":[],"diagnosticPidData":[[64768,47,100],[64768,1,517376],[64800,1,262144],[64768,5,125]]},"header":{"iwrapVer":"1.9.20","sourceSystem":"CDP","configVer":"1.1","oemName":"HUM","unitType":0,"cpVer":"7.50.1.9","igpsVer":"1.3.7","messageType":"Notification","pomVer":"1.0","headerVer":"V6","timestamp":0,"deviceType":"InDrive","visorVer":"1.4.35","transactionId":"53098471-7787-4160-94b3-cd69dcc70416","deviceSerialNo":"60DF5417","subOrganization":"HUM","organization":"HUM","imei":"60DF5417","operation":"Notification"}}"""

# %%
result = json.loads(d2)

# %%
pd.DataFrame(result)
# Out:
#                           packetType  \
# checkEngineLightFlag               D
# batteryVoltageStableTime           D
# batteryVoltageStable               D
# batteryVoltageOff                  D
# batteryCrankParamTN                D
# batteryCrankParamVN                D
# batteryCrankParamTP                D
# batteryCrankParamVP                D
# batteryCrankParamTT                D
# batteryCrankParamV0                D
# batteryVoltageMaxOn                D
# batteryVoltageMinOn                D
# batteryVoltageMaxOff               D
# batteryVoltageMinOff               D
# batteryVoltageOnAverage            D
# engineLoadMax                      D
# engineLoadAverage                  D
# rpmMax                             D
# rpmAverage                         D
# gpsSpeedAverage                    D
# vssMax                             D
# vssAverage                         D
# tcuTemperatureMin                  D
# tcuTemperatureMax                  D
# ...

# %%
result["data"]
#json means dictionary and there is a key 'data' which itself contains dictionary means we can say it as nested json file
# Out:
# {'checkEngineLightFlag': 'F',
#  'batteryVoltageStableTime': 0,
#  'batteryVoltageStable': '0',
#  'batteryVoltageOff': '12.42',
#  'batteryCrankParamTN': '-0.08',
#  'batteryCrankParamVN': '0.00',
#  'batteryCrankParamTP': '-0.08',
#  'batteryCrankParamVP': '0.00',
#  'batteryCrankParamTT': '-0.00008',
#  'batteryCrankParamV0': '0.00',
#  'batteryVoltageMaxOn': '13.05',
#  'batteryVoltageMinOn': '12.97',
#  'batteryVoltageMaxOff': '12.46',
#  'batteryVoltageMinOff': '12.36',
#  'batteryVoltageOnAverage': '13.02',
#  'engineLoadMax': '84',
#  'engineLoadAverage': '39.98',
#  'rpmMax': '3487',
#  'rpmAverage': '1431.29',
#  'gpsSpeedAverage': '21.99',
#  'vssMax': '53.44',
#  'vssAverage': '23.06',
#  'tcuTemperatureMin': '82.40',
#  'tcuTemperatureMax': '109.40',
#  'tcuTemperatureAverage': '104.87',
#  'coolantMin': '158.00',
#  'coolantMax': '188.60',
#  'coolantAverage': '180.20',
#  'packetStartLocal': 1508143346000,
#  'tripStartLocal': 1508143346000,
#  'milIndicator': 'F',
# ...

# %%
d1 = result["data"]
#pd.DataFrame(d1)
#this will not work as d1 contains unequal no. of values for particular keys
#i.e. 'diagnosticTroubleCodeData' contains unequal no. of data
#so we have to delete this to see the output in table form

# %%
del d1["diagnosticTroubleCodeData"]

# %%
pd.DataFrame(d1)
# Out:
#   checkEngineLightFlag  batteryVoltageStableTime batteryVoltageStable  \
# 0                    F                         0                    0
# 1                    F                         0                    0
# 2                    F                         0                    0
# 3                    F                         0                    0
#
#   batteryVoltageOff batteryCrankParamTN batteryCrankParamVN  \
# 0             12.42               -0.08                0.00
# 1             12.42               -0.08                0.00
# 2             12.42               -0.08                0.00
# 3             12.42               -0.08                0.00
#
#   batteryCrankParamTP batteryCrankParamVP batteryCrankParamTT  \
# 0               -0.08                0.00            -0.00008
# 1               -0.08                0.00            -0.00008
# 2               -0.08                0.00            -0.00008
# ...

# %%
url = "https://api.github.com/repos/pandas-dev/pandas/issues"

# %%
pd.read_json(url)
# Out:
#                                                   url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# ...

# %%
#load data from the url , here we are using request method

# %%
# !pip install requests
# Out:
# ...
#      |████████████████████████████████| 62 kB 1.7 MB/s  eta 0:00:01
# ...
#      |████████████████████████████████| 61 kB 233 kB/s  eta 0:00:01
# ...
#      |████████████████████████████████| 162 kB 63.0 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 141 kB 63.7 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 104 kB 63.3 MB/s eta 0:00:01
# ...
#   WARNING: The script normalizer is installed in '/config/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# ...

# %%
import requests
data = requests.get(url)
#loading data in raw format (means here in jason formmat) and not in tabular form

# %%
data # 200 is a code for succesfull request
# Out:
# <Response [200]>

# %%
data1 = data.json()

# %%
data1 #so now our data is available in row format
# Out:
# [{'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/56908',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/56908/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/56908/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/56908/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/56908',
#   'id': 2083833260,
#   'node_id': 'I_kwDOAA0YD858NMWs',
#   'number': 56908,
#   'title': "BUG: Can't get hdf5 data exrport from .NET framework",
#   'user': {'login': 'chuongmep',
#    'id': 31106432,
#    'node_id': 'MDQ6VXNlcjMxMTA2NDMy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/31106432?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/chuongmep',
#    'html_url': 'https://github.com/chuongmep',
# ...

# %%
len(data1)
# Out:
# 30

# %%
data1[0]['user']
# Out:
# {'login': 'chuongmep',
#  'id': 31106432,
#  'node_id': 'MDQ6VXNlcjMxMTA2NDMy',
#  'avatar_url': 'https://avatars.githubusercontent.com/u/31106432?v=4',
#  'gravatar_id': '',
#  'url': 'https://api.github.com/users/chuongmep',
#  'html_url': 'https://github.com/chuongmep',
#  'followers_url': 'https://api.github.com/users/chuongmep/followers',
#  'following_url': 'https://api.github.com/users/chuongmep/following{/other_user}',
#  'gists_url': 'https://api.github.com/users/chuongmep/gists{/gist_id}',
#  'starred_url': 'https://api.github.com/users/chuongmep/starred{/owner}{/repo}',
#  'subscriptions_url': 'https://api.github.com/users/chuongmep/subscriptions',
#  'organizations_url': 'https://api.github.com/users/chuongmep/orgs',
#  'repos_url': 'https://api.github.com/users/chuongmep/repos',
#  'events_url': 'https://api.github.com/users/chuongmep/events{/privacy}',
#  'received_events_url': 'https://api.github.com/users/chuongmep/received_events',
#  'type': 'User',
# ...

# %%
data1[0]['user']['id']
# Out:
# 31106432

# %%
#to get user id for all these 30 dictinaries
for i in range(len(data1)):
  print(data1[i]['user']['id'])
# Out:
# 31106432
# 10058240
# 91160475
# 77875500
# 35613487
# 76517593
# 45562402
# 45109652
# 91160475
# 47963215
# 25203655
# 25203655
# 6618166
# 17410600
# 8392324
# 8392324
# 16797137
# 15113894
# 15113894
# 6618166
# 33491632
# 109252777
# 153054577
# 153054577
# 153054577
# 10647082
# 16045385
# 10537808
# 149194323
# 117079880

# %%
#to fetch particular columns
pd.DataFrame(data1 , columns=['id', 'url' , 'repository_url' , 'labels_url' , 'user'])
# Out:
#             id                                                url  \
# 0   2083833260  https://api.github.com/repos/pandas-dev/pandas...
# 1   2083493714  https://api.github.com/repos/pandas-dev/pandas...
# 2   2083423129  https://api.github.com/repos/pandas-dev/pandas...
# 3   2083172588  https://api.github.com/repos/pandas-dev/pandas...
# 4   2082962042  https://api.github.com/repos/pandas-dev/pandas...
# 5   2082896937  https://api.github.com/repos/pandas-dev/pandas...
# 6   2082867564  https://api.github.com/repos/pandas-dev/pandas...
# 7   2082856032  https://api.github.com/repos/pandas-dev/pandas...
# 8   2082776498  https://api.github.com/repos/pandas-dev/pandas...
# 9   2082697567  https://api.github.com/repos/pandas-dev/pandas...
# 10  2082652795  https://api.github.com/repos/pandas-dev/pandas...
# 11  2082642253  https://api.github.com/repos/pandas-dev/pandas...
# 12  2082445854  https://api.github.com/repos/pandas-dev/pandas...
# ...

# %%
df = pd.DataFrame(data1 , columns=['id', 'url' , 'repository_url' , 'labels_url' , 'user'])

# %%
df.to_csv("Json_Response.csv")
