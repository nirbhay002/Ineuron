# %%
import pandas as pd

# %%
#most powerfull library usefull in different diffrerrnt dataset operation
#here we deal with different different types of files 
#pandas is the kind of library which will be able to handle all of this file read write manipulation filter each and every kind of operation in a easy possible ways

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
ls
# Out:
# drive/  sample_data/

# %%
pd.read_csv('/content/drive/MyDrive/Data set for Data science/Pandas /dtataCSV.csv', header= None)
# Out:
#               0                         1                          2        3  \
# 0         Name                  Email Id                     Address  pincode
# 1    Anil Kamat    anilkamat294@gmail.com     block A-2 , sant nagar   110084
# 2  Anisha Kamat  anishakamat294@gmail.com   Block b-2 , Shakti nagar   110006
# 3   Ankur prash    ankurprash23@gmail.com  Block c- 2, Shastri Nagar   110006
#
#           4
# 0   Surname
# 1     kumar
# 2  vashisth
# 3       pal

# %%
 #limitation of pandas is that it is usefull for structured format data only

# %%
#entire table created by pandas is called data frmae

# %%
type(table)
# Out:
# pandas.core.frame.DataFrame

# %%
table
# Out:
#           Name                  Email Id                     Address  pincode  \
# 0    Anil Kamat    anilkamat294@gmail.com     block A-2 , sant nagar   110084
# 1  Anisha Kamat  anishakamat294@gmail.com   Block b-2 , Shakti nagar   110006
# 2   Ankur prash    ankurprash23@gmail.com  Block c- 2, Shastri Nagar   110006
#
#     Surname
# 0     kumar
# 1  vashisth
# 2       pal

# %%
pd.read_csv('/content/drive/MyDrive/Data set for Data science/Pandas /dtataCSV.csv', names = ["a","b","c","d","e","t"])
# Out:
#               a                         b                          c        d  \
# 0         Name                  Email Id                     Address  pincode
# 1    Anil Kamat    anilkamat294@gmail.com     block A-2 , sant nagar   110084
# 2  Anisha Kamat  anishakamat294@gmail.com   Block b-2 , Shakti nagar   110006
# 3   Ankur prash    ankurprash23@gmail.com  Block c- 2, Shastri Nagar   110006
#
#           e   t
# 0   Surname NaN
# 1     kumar NaN
# 2  vashisth NaN
# 3       pal NaN

# %%
pd.read_csv('/content/drive/MyDrive/Data set for Data science/Pandas /dtataCSV.csv', names = ["a","b","c"])
# Out:
#                                                                a        b  \
# Name         Email Id                                    Address  pincode
# Anil Kamat   anilkamat294@gmail.com       block A-2 , sant nagar   110084
# Anisha Kamat anishakamat294@gmail.com   Block b-2 , Shakti nagar   110006
# Ankur prash  ankurprash23@gmail.com    Block c- 2, Shastri Nagar   110006
#
#                                               c
# Name         Email Id                   Surname
# Anil Kamat   anilkamat294@gmail.com       kumar
# Anisha Kamat anishakamat294@gmail.com  vashisth
# Ankur prash  ankurprash23@gmail.com         pal

# %%
pd.read_csv('/content/drive/MyDrive/Data set for Data science/Pandas /dtataCSV@.csv', sep = '@')
# Out:
#                        Name   Email Id                     Address  pincode  \
# Anil Kamat      anilkamat294  gmail.com     block A-2 @ sant nagar   110084
# Anisha Kamat  anishakamat294  gmail.com   Block b-2 @ Shakti nagar   110006
# Ankur prash     ankurprash23  gmail.com  Block c- 2@ Shastri Nagar   110006
#
#                Surname
# Anil Kamat       kumar
# Anisha Kamat  vashisth
# Ankur prash        pal

# %%
pd.read_csv('/content/drive/MyDrive/Data set for Data science/Pandas /dtataCSV.csv', skiprows = [1])
# Out:
#           Name                  Email Id                     Address  pincode  \
# 0  Anisha Kamat  anishakamat294@gmail.com   Block b-2 , Shakti nagar   110006
# 1   Ankur prash    ankurprash23@gmail.com  Block c- 2, Shastri Nagar   110006
#
#     Surname
# 0  vashisth
# 1       pal

# %%
table = pd.read_csv('/content/drive/MyDrive/Data set for Data science/Pandas /dtataCSV.csv')

# %%
table.dtypes
# Out:
# Name         object
# Email Id     object
# Address      object
# pincode       int64
# Surname      object
# dtype: object

# %%
#in case of pandas string data types is called object

# %%
# head upar se kitna data chaiye 
# tail niche se kitna data chaiye

# %%
table.columns
# Out:
# Index(['Name ', 'Email Id ', 'Address', 'pincode', 'Surname'], dtype='object')

# %%
table['Email Id ']
# Out:
# 0      anilkamat294@gmail.com
# 1    anishakamat294@gmail.com
# 2      ankurprash23@gmail.com
# Name: Email Id , dtype: object

# %%
a= table['Email Id ']

# %%
type(a)
# Out:
# pandas.core.series.Series

# %%
# series is equivalant to list , one single row and one single column

# %%
table[['Name ', 'Email Id ']]
# Out:
#           Name                  Email Id
# 0    Anil Kamat    anilkamat294@gmail.com
# 1  Anisha Kamat  anishakamat294@gmail.com
# 2   Ankur prash    ankurprash23@gmail.com

# %%
df2 = table[['Name ', 'Email Id ']]
type(df2)
# Out:
# pandas.core.frame.DataFrame

# %%
df3 = table[['Name ']]
type(df3)
# Out:
# pandas.core.frame.DataFrame

# %%
#double bracket = data frame , single bracket = series

# %%
pd.read_excel("/content/drive/MyDrive/Data set for Data science/Pandas /dtataCSV.xlsx")
# Out:
#           Name                  Email Id                     Address  pincode  \
# 0    Anil Kamat    anilkamat294@gmail.com     block A-2 , sant nagar   110084
# 1  Anisha Kamat  anishakamat294@gmail.com   Block b-2 , Shakti nagar   110006
# 2   Ankur prash    ankurprash23@gmail.com  Block c- 2, Shastri Nagar   110006
#
#     Surname
# 0     kumar
# 1  vashisth
# 2       pal

# %%
pd.read_excel("/content/drive/MyDrive/Data set for Data science/Pandas /LUSID Excel - Manage Orders.xlsx")
# Out:
#     Unnamed: 0                                   Unnamed: 1  \
# 0          NaN  This sheet allows you to manage executions:
# 1          NaN                           1. List executions
# 2          NaN                             2. Get execution
# 3          NaN                         3. Upsert executions
# 4          NaN                                          NaN
# ..         ...                                          ...
# 65         NaN                                          NaN
# 66         NaN                                          NaN
# 67         NaN                                          NaN
# 68         NaN                                          NaN
# 69         NaN                                          NaN
#
#            Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7  \
# 0                 NaN        NaN        NaN        NaN        NaN        NaN
# 1                 NaN        NaN        NaN        NaN        NaN        NaN
# ...

# %%
# by default pandas read 1st excel sheets but using sheet_name we can extract data from other excel sheet

# %%
pd.read_excel("/content/drive/MyDrive/Data set for Data science/Pandas /LUSID Excel - Manage Orders.xlsx", sheet_name = "Allocations")
# Out:
#     Unnamed: 0                                    Unnamed: 1       Unnamed: 2  \
# 0          NaN  This sheet allows you to manage Allocations:              NaN
# 1          NaN                            1. ListAllocations              NaN
# 2          NaN                              2. GetAllocation              NaN
# 3          NaN                          3. UpsertAllocations              NaN
# 4          NaN                                           NaN              NaN
# ..         ...                                           ...              ...
# 60         NaN                                           NaN              NaN
# 61         NaN                                           NaN              NaN
# 62         NaN                                           NaN             Code
# 63         NaN                                           NaN  MyAllocation001
# 64         NaN                                           NaN  MyAllocation002
#
# ...

# %%
df = pd.ExcelFile("/content/drive/MyDrive/Data set for Data science/Pandas /LUSID Excel - Manage Orders.xlsx")

# %%
#how we can get all sheet nasme
df.sheet_names
# Out:
# ['Executions', 'Orders', 'Allocations', 'Placements', 'Blocks']

# %%
for i in df.sheet_names:
  pd.read_excel("/content/drive/MyDrive/Data set for Data science/Pandas /LUSID Excel - Manage Orders.xlsx" , sheet_name =   i)

# %%
pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# #Read Html

# %%
pd.read_html("https://www.basketball-reference.com/leagues/")
# Out:
# [   Unnamed: 0_level_0 Unnamed: 1_level_0     Unnamed: 2_level_0  \
#                 Season                 Lg               Champion
#  0             2022-23                NBA                    NaN
#  1             2021-22                NBA  Golden State Warriors
#  2             2020-21                NBA        Milwaukee Bucks
#  3             2019-20                NBA     Los Angeles Lakers
#  4             2018-19                NBA        Toronto Raptors
#  ..                ...                ...                    ...
#  81            1950-51                NBA       Rochester Royals
#  82            1949-50                NBA     Minneapolis Lakers
#  83            1948-49                BAA     Minneapolis Lakers
#  84            1947-48                BAA      Baltimore Bullets
#  85            1946-47                BAA  Philadelphia Warriors
#
#         Award Winners                          Top Performers  \
# ...

# %%
#this data is not in readable format
df = pd.read_html("https://www.basketball-reference.com/leagues/")
type(df)
# Out:
# list

# %%
#data is in list format , I am not happy with this format , i want full tabular form of data

# %%
len(df)
# Out:
# 1

# %%
df[0]
# Out:
#    Unnamed: 0_level_0 Unnamed: 1_level_0     Unnamed: 2_level_0  \
#                Season                 Lg               Champion
# 0             2022-23                NBA                    NaN
# 1             2021-22                NBA  Golden State Warriors
# 2             2020-21                NBA        Milwaukee Bucks
# 3             2019-20                NBA     Los Angeles Lakers
# 4             2018-19                NBA        Toronto Raptors
# ..                ...                ...                    ...
# 81            1950-51                NBA       Rochester Royals
# 82            1949-50                NBA     Minneapolis Lakers
# 83            1948-49                BAA     Minneapolis Lakers
# 84            1947-48                BAA      Baltimore Bullets
# 85            1946-47                BAA  Philadelphia Warriors
#
#        Award Winners                          Top Performers  \
#                  MVP Rookie of the Year               Points
# ...

# %%
type(df[0])
# Out:
# pandas.core.frame.DataFrame

# %%
# read_table() sirf tabular data ko hi read karta hai

# %%
df1 = df[0]
df1.columns
# Out:
# MultiIndex([('Unnamed: 0_level_0',             'Season'),
#             ('Unnamed: 1_level_0',                 'Lg'),
#             ('Unnamed: 2_level_0',           'Champion'),
#             (     'Award Winners',                'MVP'),
#             (     'Award Winners', 'Rookie of the Year'),
#             (    'Top Performers',             'Points'),
#             (    'Top Performers',           'Rebounds'),
#             (    'Top Performers',            'Assists'),
#             (    'Top Performers',         'Win Shares')],
#            )

# %%
df1.head()
# Out:
#   Unnamed: 0_level_0 Unnamed: 1_level_0     Unnamed: 2_level_0  \
#               Season                 Lg               Champion
# 0            2022-23                NBA                    NaN
# 1            2021-22                NBA  Golden State Warriors
# 2            2020-21                NBA        Milwaukee Bucks
# 3            2019-20                NBA     Los Angeles Lakers
# 4            2018-19                NBA        Toronto Raptors
#
#       Award Winners                       Top Performers                      \
#                 MVP Rookie of the Year            Points            Rebounds
# 0               NaN                NaN   J. Tatum (2146)    D. Sabonis (921)
# 1          N. Jokić          S. Barnes   T. Young (2155)     N. Jokić (1019)
# 2          N. Jokić            L. Ball   S. Curry (2015)     R. Gobert (960)
# 3  G. Antetokounmpo          J. Morant  J. Harden (2335)     R. Gobert (916)
# ...

# %%
df1.tail(3)
# Out:
#    Unnamed: 0_level_0 Unnamed: 1_level_0     Unnamed: 2_level_0 Award Winners  \
#                Season                 Lg               Champion           MVP
# 83            1948-49                BAA     Minneapolis Lakers           NaN
# 84            1947-48                BAA      Baltimore Bullets           NaN
# 85            1946-47                BAA  Philadelphia Warriors           NaN
#
#                             Top Performers                               \
#    Rookie of the Year               Points Rebounds             Assists
# 83         H. Shannon      G. Mikan (1698)      NaN     B. Davies (321)
# 84         P. Hoffman  M. Zaslofsky (1007)      NaN    H. Dallmar (120)
# 85                NaN      J. Fulks (1389)      NaN  E. Calverley (202)
#
#
#            Win Shares
# 83    G. Mikan (20.9)
# 84  B. Feerick (10.5)
# 85  B. Feerick (18.6)

# %%
df1.dtypes
# Out:
# Unnamed: 0_level_0  Season                object
# Unnamed: 1_level_0  Lg                    object
# Unnamed: 2_level_0  Champion              object
# Award Winners       MVP                   object
#                     Rookie of the Year    object
# Top Performers      Points                object
#                     Rebounds              object
#                     Assists               object
#                     Win Shares            object
# dtype: object

# %%
df1[["Unnamed: 0_level_0" , "Unnamed: 1_level_0"]]
# Out:
#    Unnamed: 0_level_0 Unnamed: 1_level_0
#                Season                 Lg
# 0             2022-23                NBA
# 1             2021-22                NBA
# 2             2020-21                NBA
# 3             2019-20                NBA
# 4             2018-19                NBA
# ..                ...                ...
# 81            1950-51                NBA
# 82            1949-50                NBA
# 83            1948-49                BAA
# 84            1947-48                BAA
# 85            1946-47                BAA
#
# [86 rows x 2 columns]

# %%
df1.to_csv("NBA.csv")

# %%
#to remove indexes we can use the command index = false 
df5 = pd.read_html('https://stats.espncricinfo.com/ci/engine/records/averages/batting.html?class=3;id=6;type=team')

# %%
df5[0]
# Out:
#                 Player       Span  Mat Inns  NO  Runs   HS    Ave   BF  \
# 0           AB Agarkar  2006-2007    4    2   0    15   14   7.50   11
# 1             KK Ahmed  2018-2019   14    1   1     1   1*      -    1
# 2            S Aravind  2015-2015    1    -   -     -    -      -    -
# 3       Arshdeep Singh  2022-2023   26    5   5     6   2*      -   10
# 4             R Ashwin  2010-2022   65   19  12   184  31*  26.28  160
# ..                 ...        ...  ...  ...  ..   ...  ...    ...  ...
# 97       R Vinay Kumar  2010-2013    9    1   1     2   2*      -    4
# 98   Washington Sundar  2017-2023   35   14   4   107   50  10.70   70
# 99            SA Yadav  2021-2023   48   46  10  1675  117  46.52  953
# 100           UT Yadav  2012-2022    9    2   1    22  20*  22.00   21
# 101       Yuvraj Singh  2007-2017   58   51   9  1177  77*  28.02  863
#
#          SR 100  50  0   4s  6s
# 0    136.36   0   0  0    2   0
# 1    100.00   0   0  0    0   0
# ...

# %%
len(df5)
# Out:
# 3

# %%
df5[0].to_csv("cricket.csv", index = False)

# %%
#optimal character recognization

# %%
d = """
{"name": "sudhanshu Kumar",
	"email id": "sudhanshu234@gmail.com",
	"tech": ["ML", "DL"],
	"platform": ["Tech Neuron", "Kids Neuron"]
}
"""
# we have to convert this data into data frame format

# %%
pd.DataFrame(d)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-3449b472dc69> in <cell line: 1>()
# ----> 1 pd.DataFrame(d)
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     754         else:
#     755             if index is None or columns is None:
# --> 756                 raise ValueError("DataFrame constructor not properly called!")
#     757
#     758             # Argument 1 to "ensure_index" has incompatible type "Collection[Any]";
#
# ValueError: DataFrame constructor not properly called!

# %%
import json
#javascript Object notation , a file system or a dta which is avialable in a dictionary format , that is called JSON
# across industry its been use a lot because it is one of the light weight format to transfer a data from one place to another 
#previously we are using a XMl format to transfer a data from one format to another format

# %%
#always remember to validate json otherwise it causes an error

# %%
result = json.loads(d)

# %%
type(result)
# Out:
# dict

# %%
pd.DataFrame(result)
# Out:
#               name                email id tech     platform
# 0  sudhanshu Kumar  sudhanshu234@gmail.com   ML  Tech Neuron
# 1  sudhanshu Kumar  sudhanshu234@gmail.com   DL  Kids Neuron

# %%
pd.DataFrame(result['tech'])
# Out:
#     0
# 0  ML
# 1  DL

# %%
result['tech']
# Out:
# ['ML', 'DL']

# %%
d2 ="""{"packetType":"D","data":{"checkEngineLightFlag":"F","batteryVoltageStableTime":0,"batteryVoltageStable":"0","batteryVoltageOff":"12.42","batteryCrankParamTN":"-0.08","batteryCrankParamVN":"0.00","batteryCrankParamTP":"-0.08","batteryCrankParamVP":"0.00","batteryCrankParamTT":"-0.00008","batteryCrankParamV0":"0.00","batteryVoltageMaxOn":"13.05","batteryVoltageMinOn":"12.97","batteryVoltageMaxOff":"12.46","batteryVoltageMinOff":"12.36","batteryVoltageOnAverage":"13.02","engineLoadMax":"84","engineLoadAverage":"39.98","rpmMax":"3487","rpmAverage":"1431.29","gpsSpeedAverage":"21.99","vssMax":"53.44","vssAverage":"23.06","tcuTemperatureMin":"82.40","tcuTemperatureMax":"109.40","tcuTemperatureAverage":"104.87","coolantMin":"158.00","coolantMax":"188.60","coolantAverage":"180.20","packetStartLocal":1508143346000,"tripStartLocal":1508143346000,"milIndicator":"F","monitorsNotReady":0,"imei":"60DF5417","gatewayTs":1515613306592,"diagnosticTroubleCodeData":[],"diagnosticPidData":[[64768,47,100],[64768,1,517376],[64800,1,262144],[64768,5,125]]},"header":{"iwrapVer":"1.9.20","sourceSystem":"CDP","configVer":"1.1","oemName":"HUM","unitType":0,"cpVer":"7.50.1.9","igpsVer":"1.3.7","messageType":"Notification","pomVer":"1.0","headerVer":"V6","timestamp":0,"deviceType":"InDrive","visorVer":"1.4.35","transactionId":"53098471-7787-4160-94b3-cd69dcc70416","deviceSerialNo":"60DF5417","subOrganization":"HUM","organization":"HUM","imei":"60DF5417","operation":"Notification"}}"""

# %%
result = json.loads(d2)

# %%
pd.DataFrame(result)
# Out:
#                           packetType  \
# checkEngineLightFlag               D
# batteryVoltageStableTime           D
# batteryVoltageStable               D
# batteryVoltageOff                  D
# batteryCrankParamTN                D
# batteryCrankParamVN                D
# batteryCrankParamTP                D
# batteryCrankParamVP                D
# batteryCrankParamTT                D
# batteryCrankParamV0                D
# batteryVoltageMaxOn                D
# batteryVoltageMinOn                D
# batteryVoltageMaxOff               D
# batteryVoltageMinOff               D
# batteryVoltageOnAverage            D
# engineLoadMax                      D
# engineLoadAverage                  D
# rpmMax                             D
# rpmAverage                         D
# gpsSpeedAverage                    D
# vssMax                             D
# vssAverage                         D
# tcuTemperatureMin                  D
# tcuTemperatureMax                  D
# ...

# %%
d1 =result["data"]

# %%
del d1["diagnosticTroubleCodeData"]

# %%
pd.DataFrame(d1)
# Out:
#   checkEngineLightFlag  batteryVoltageStableTime batteryVoltageStable  \
# 0                    F                         0                    0
# 1                    F                         0                    0
# 2                    F                         0                    0
# 3                    F                         0                    0
#
#   batteryVoltageOff batteryCrankParamTN batteryCrankParamVN  \
# 0             12.42               -0.08                0.00
# 1             12.42               -0.08                0.00
# 2             12.42               -0.08                0.00
# 3             12.42               -0.08                0.00
#
#   batteryCrankParamTP batteryCrankParamVP batteryCrankParamTT  \
# 0               -0.08                0.00            -0.00008
# 1               -0.08                0.00            -0.00008
# 2               -0.08                0.00            -0.00008
# ...

# %%
url = "https://api.github.com/repos/pandas-dev/pandas/issues"

# %%
pd.read_json(url)
# Out:
#                                                   url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# ...

# %%
#load data from the url , here we are using request method

# %%
import requests
data = requests.get(url)

# %%
data # 200 is a code for succesfull request
# Out:
# <Response [200]>

# %%
data1 = data.json()

# %%
data1
# Out:
# [{'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52330',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52330/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52330/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52330/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/52330',
#   'id': 1649817076,
#   'node_id': 'PR_kwDOAA0YD85NYFBl',
#   'number': 52330,
#   'title': 'ENH: Implement .dt.year for ArrowExtensionArray',
#   'user': {'login': 'mroeschke',
#    'id': 10647082,
#    'node_id': 'MDQ6VXNlcjEwNjQ3MDgy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/10647082?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mroeschke',
#    'html_url': 'https://github.com/mroeschke',
# ...

# %%
len(data1)
# Out:
# 30

# %%
data1[0]['user']
# Out:
# {'login': 'mroeschke',
#  'id': 10647082,
#  'node_id': 'MDQ6VXNlcjEwNjQ3MDgy',
#  'avatar_url': 'https://avatars.githubusercontent.com/u/10647082?v=4',
#  'gravatar_id': '',
#  'url': 'https://api.github.com/users/mroeschke',
#  'html_url': 'https://github.com/mroeschke',
#  'followers_url': 'https://api.github.com/users/mroeschke/followers',
#  'following_url': 'https://api.github.com/users/mroeschke/following{/other_user}',
#  'gists_url': 'https://api.github.com/users/mroeschke/gists{/gist_id}',
#  'starred_url': 'https://api.github.com/users/mroeschke/starred{/owner}{/repo}',
#  'subscriptions_url': 'https://api.github.com/users/mroeschke/subscriptions',
#  'organizations_url': 'https://api.github.com/users/mroeschke/orgs',
#  'repos_url': 'https://api.github.com/users/mroeschke/repos',
#  'events_url': 'https://api.github.com/users/mroeschke/events{/privacy}',
#  'received_events_url': 'https://api.github.com/users/mroeschke/received_events',
#  'type': 'User',
# ...

# %%
for i in range(len(data1)):
  print(data1[0]['user']['id'])
# Out:
# 10647082
# 10647082
# 10647082
# 10647082
# 10647082
# 10647082
# 10647082
# 10647082
# 10647082
# 10647082
# 10647082
# 10647082
# 10647082
# 10647082
# 10647082
# 10647082
# 10647082
# 10647082
# 10647082
# 10647082
# 10647082
# 10647082
# 10647082
# 10647082
# 10647082
# 10647082
# 10647082
# 10647082
# 10647082
# 10647082

# %%
df = pd.DataFrame(data1 , columns=['id', 'url' , 'repository' , 'labels_url' , 'user'])

# %%
df.to_csv("Json_Response.csv")

# %%
data1[0]['user']
# Out:
# {'login': 'mroeschke',
#  'id': 10647082,
#  'node_id': 'MDQ6VXNlcjEwNjQ3MDgy',
#  'avatar_url': 'https://avatars.githubusercontent.com/u/10647082?v=4',
#  'gravatar_id': '',
#  'url': 'https://api.github.com/users/mroeschke',
#  'html_url': 'https://github.com/mroeschke',
#  'followers_url': 'https://api.github.com/users/mroeschke/followers',
#  'following_url': 'https://api.github.com/users/mroeschke/following{/other_user}',
#  'gists_url': 'https://api.github.com/users/mroeschke/gists{/gist_id}',
#  'starred_url': 'https://api.github.com/users/mroeschke/starred{/owner}{/repo}',
#  'subscriptions_url': 'https://api.github.com/users/mroeschke/subscriptions',
#  'organizations_url': 'https://api.github.com/users/mroeschke/orgs',
#  'repos_url': 'https://api.github.com/users/mroeschke/repos',
#  'events_url': 'https://api.github.com/users/mroeschke/events{/privacy}',
#  'received_events_url': 'https://api.github.com/users/mroeschke/received_events',
#  'type': 'User',
# ...
